# %% [markdown]
# <a href="https://colab.research.google.com/github/fcosilva/hola-mundo/blob/main/B_T2_SilvaFrancisco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. **Hola Mundo:** Escribe un programa que imprima "Hola, Mundo!" en la pantalla.

# %%
print("Hola, Mundo!")
# Out:
# Hola, Mundo!

# %% [markdown]
# 2. **Suma de dos números:** Escribe un programa que pida al usuario dos números y los sume.
